# %%
from PIL import Image
import os, os.path
import shutil

# %%
current_dir = os.getcwd()
path_Donnee_DP_moitié_Autre = os.path.join(current_dir,'Donnee_DP_moitié_Autre')

# %%
for d in os.listdir(path_Donnee_DP_moitié_Autre):
    for dossier in os.listdir(os.path.join(path_Donnee_DP_moitié_Autre,d)):
        i = 0
        for classe in os.listdir(os.path.join(path_Donnee_DP_moitié_Autre,d,dossier)):
            if dossier == 'Autre' : 
                i = i+1
                if i%2 :
                    print(os.path.join(path_Donnee_DP_moitié_Autre,d,dossier,classe))
                    os.remove(os.path.join(path_Donnee_DP_moitié_Autre,d,dossier,classe))
# Out:
# C:\Users\dimii\Documents\INSA\5A\Projet_5BIM\Projet5BIM\Donnee_DP_moitié_Autre\test\Autre\100_20.png
# C:\Users\dimii\Documents\INSA\5A\Projet_5BIM\Projet5BIM\Donnee_DP_moitié_Autre\test\Autre\100_59.png
# C:\Users\dimii\Documents\INSA\5A\Projet_5BIM\Projet5BIM\Donnee_DP_moitié_Autre\test\Autre\102_31.png
# C:\Users\dimii\Documents\INSA\5A\Projet_5BIM\Projet5BIM\Donnee_DP_moitié_Autre\test\Autre\103_72.png
# C:\Users\dimii\Documents\INSA\5A\Projet_5BIM\Projet5BIM\Donnee_DP_moitié_Autre\test\Autre\104_64.png
# C:\Users\dimii\Documents\INSA\5A\Projet_5BIM\Projet5BIM\Donnee_DP_moitié_Autre\test\Autre\105_43.png
# C:\Users\dimii\Documents\INSA\5A\Projet_5BIM\Projet5BIM\Donnee_DP_moitié_Autre\test\Autre\106_32.png
# C:\Users\dimii\Documents\INSA\5A\Projet_5BIM\Projet5BIM\Donnee_DP_moitié_Autre\test\Autre\106_59.png
# C:\Users\dimii\Documents\INSA\5A\Projet_5BIM\Projet5BIM\Donnee_DP_moitié_Autre\test\Autre\108_17.png
# ...
