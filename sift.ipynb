# %%
pip uninstall opencv-contrib-python

# %%
pip install opencv-contrib-python

# %%
import cv2 
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Reading image

# %%
img1 = cv2.imread('Selection_imagettes/Carcasse/236_29.png')

# %%
gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)

# %% [markdown]
# # Keypoints

# %%
sift = cv2.xfeatures2d.SIFT_create()
keypoints_1, descriptors_1 = sift.detectAndCompute(img1,None)

# %% [markdown]
# # Print

# %%
img_1 = cv2.drawKeypoints(gray1,keypoints_1,img1)
plt.imshow(img_1)

# %% [markdown]
# Très chelou il n'y a pas de keypoints.

# %% [markdown]
# # Deuxieme test

# %%
img = cv2.imread('Selection_imagettes/Carcasse/236_29.png')
gray= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
sift = cv2.xfeatures2d.SIFT_create()

# %%
kp = sift.detect(gray,None)

# %%
img=cv2.drawKeypoints(gray,kp,img,color=(0,0,255))

# %%
cv2.imwrite('sift_keypoints_contrasted_im_2.jpg',img)
# Out:
# True

# %%
img=cv2.drawKeypoints(gray,kp,img,flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS,color=(0,0,255))
cv2.imwrite('sift_keypoints_gradient_contrasted_im_2.jpg',img)
# Out:
# True

# %%
new_im = cv2.imread('sift_keypoints_gradient_contrasted_im_2.jpg')
plt.imshow(new_im)
